# %%
import pandas as pd

# %%
#importing dataSet
data = pd.read_csv('/kaggle/input/dataset-mashrooms/dataset_Mashrooms.csv')
data.columns

# %%
data['Cap color']

# %%
data.isnull().sum()

# %% [markdown]
# #one hot encoded of data

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
#using data['Cap color'] as an array
data1 = np.array([['red'],
                 ['brown'],
                 ['red'],
                 ['brown']])

# %% [markdown]
# #normalisation using One Hot encoder or label Encoding
# #small data , we use Label Encoding
# #Big data , we use One Hot Encoder

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder


objecte = OneHotEncoder()
objecte.fit_transform(data['Cap color'])
